# %% [markdown]
# # Importing Pandas library for dataframes

# %%
import pandas as pd
data = pd.read_csv("ak.csv")
data
# Out:
#                  Series_Title Released_Year  Runtime  \
# 0    The Shawshank Redemption          1994  142 min
# 1               The Godfather          1972  175 min
# 2             The Dark Knight          2008  152 min
# 3      The Godfather: Part II          1974  202 min
# 4                12 Angry Men          1957   96 min
# ..                        ...           ...      ...
# 995    Breakfast at Tiffany's          1961  115 min
# 996                     Giant          1956  201 min
# 997     From Here to Eternity          1953  118 min
# 998                  Lifeboat          1944   97 min
# 999              The 39 Steps          1935   86 min
#
#                         Genre  IMDB_Rating
# 0                       Drama          9.3
# 1                Crime, Drama          9.2
# 2        Action, Crime, Drama          9.0
# 3                Crime, Drama          9.0
# 4                Crime, Drama          9.0
# ..                        ...          ...
# ...

# %%
data.shape
# Out:
# (1000, 5)

# %% [markdown]
# # Renaming the columns

# %%
data.columns = ["Title","releasing year","duration", "Genre", "Rating"]
data
# Out:
#                         Title releasing year duration  \
# 0    The Shawshank Redemption           1994  142 min
# 1               The Godfather           1972  175 min
# 2             The Dark Knight           2008  152 min
# 3      The Godfather: Part II           1974  202 min
# 4                12 Angry Men           1957   96 min
# ..                        ...            ...      ...
# 995    Breakfast at Tiffany's           1961  115 min
# 996                     Giant           1956  201 min
# 997     From Here to Eternity           1953  118 min
# 998                  Lifeboat           1944   97 min
# 999              The 39 Steps           1935   86 min
#
#                         Genre  Rating
# 0                       Drama     9.3
# 1                Crime, Drama     9.2
# 2        Action, Crime, Drama     9.0
# 3                Crime, Drama     9.0
# 4                Crime, Drama     9.0
# ..                        ...     ...
# 995    Comedy, Drama, Romance     7.6
# ...

# %%
data.head()
# Out:
#                       Title releasing year duration                 Genre  \
# 0  The Shawshank Redemption           1994  142 min                 Drama
# 1             The Godfather           1972  175 min          Crime, Drama
# 2           The Dark Knight           2008  152 min  Action, Crime, Drama
# 3    The Godfather: Part II           1974  202 min          Crime, Drama
# 4              12 Angry Men           1957   96 min          Crime, Drama
#
#    Rating
# 0     9.3
# 1     9.2
# 2     9.0
# 3     9.0
# 4     9.0

# %% [markdown]
# # Doing feature improvements by checking the missing values in the data

# %%
data.isnull().sum()
# Out:
# Title             0
# releasing year    0
# duration          0
# Genre             0
# Rating            0
# dtype: int64

# %% [markdown]
# # Output dependancy variables are selected
# Output is dependent on "Genre" and "Rating"

# %%
Out_depend = pd.get_dummies(data[['Genre', 'Rating']], columns = ['Genre'])
Out_depend
# Out:
#      Rating  Genre_Action, Adventure  Genre_Action, Adventure, Biography  \
# 0       9.3                        0                                   0
# 1       9.2                        0                                   0
# 2       9.0                        0                                   0
# 3       9.0                        0                                   0
# 4       9.0                        0                                   0
# ..      ...                      ...                                 ...
# 995     7.6                        0                                   0
# 996     7.6                        0                                   0
# 997     7.6                        0                                   0
# 998     7.6                        0                                   0
# 999     7.6                        0                                   0
#
#      Genre_Action, Adventure, Comedy  Genre_Action, Adventure, Crime  \
# ...

# %% [markdown]
# # Splitting the data into train and test datasets

# %%
from sklearn.model_selection import train_test_split
Target_variable = data["Title"]
Out_depend_train, Out_depend_test, Target_variable_train, Target_variable_test = train_test_split(Out_depend, Target_variable, test_size = 0.2, random_state = 43 )

# %% [markdown]
# # Applying the algorithms

# %%
from sklearn.neighbors import NearestNeighbors

Algo = NearestNeighbors(n_neighbors = 5, algorithm = 'ball_tree')
Algo.fit(Out_depend_train)
# Out:
# NearestNeighbors(algorithm='ball_tree')

# %% [markdown]
# # Movie index printing and recommending movies according to the genre and Rating

# %%
def Movie_index(df):
  Movie_title = input("Movie name : ").lower().strip()
  df['Title'] = df["Title"].str.lower()
  if Movie_title in df["Title"].values:
    distances, indices = Algo.kneighbors(Out_depend.iloc[4].values.reshape(1, -1))
    for i in indices[0]:
      print(df.iloc[i]['Title'])

    return df[df["Title"] == Movie_title].index[0]
  else:
    print("This movie is not in the data")
    return None

Index = Movie_index(data)
print(f"Movie index is : {Index}")
# Out:
# Movie name : The godfather
# bin-jip
# the sixth sense
# touch of evil
# the exorcist
# sen to chihiro no kamikakushi
# Movie index is : 1
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but NearestNeighbors was fitted with feature names
#   warnings.warn(
